# %% [markdown]
# <a href="https://colab.research.google.com/github/Donsufia/Engr-Donald-Hamoye_premier-Project/blob/main/Hamoye-Premire-Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Nigeria= pd.read_csv("/content/drive/MyDrive/Team Ansible/2.Datasets/Raw Data/Nigeria.csv")
Nigeria
# Out:
#      Year  Country Country Code              Region  \
# 0    2000  Nigeria          NGA  Sub Saharan Africa
# 1    2000  Nigeria          NGA  Sub Saharan Africa
# 2    2000  Nigeria          NGA  Sub Saharan Africa
# 3    2000  Nigeria          NGA  Sub Saharan Africa
# 4    2000  Nigeria          NGA  Sub Saharan Africa
# ..    ...      ...          ...                 ...
# 235  2023  Nigeria          NGA  Sub Saharan Africa
# 236  2023  Nigeria          NGA  Sub Saharan Africa
# 237  2023  Nigeria          NGA  Sub Saharan Africa
# 238  2023  Nigeria          NGA  Sub Saharan Africa
# 239  2023  Nigeria          NGA  Sub Saharan Africa
#
#                                                Element  \
# 0                                    Remittance inflow
# 1               Gross domestic product, current prices
# 2                                       Percent of GDP
# 3               Gross domestic product, current prices
# 4                   Inflation, average consumer prices
# ...

# %%
Nigeria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          240 non-null    int64
#  1   Country       240 non-null    object
#  2   Country Code  240 non-null    object
#  3   Region        240 non-null    object
#  4   Element       240 non-null    object
#  5   Unit          240 non-null    object
#  6   Scale         240 non-null    object
#  7   Value         174 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 15.1+ KB

# %%
unique_elements = Nigeria['Element'].unique()
print(unique_elements)
# Out:
# ['Remittance inflow' 'Gross domestic product, current prices'
#  'Percent of GDP' 'Inflation, average consumer prices'
#  'Human Development Index'
#  'Households and NPISHs Final consumption expenditure'
#  'Multidimensional poverty headcount ratio (World Bank)'
#  'Unemployment rate']

# %%
grouped_data = Nigeria.groupby('Element')
# Print the grouped data
print(grouped_data)

# %%
remittance_inflow_df = grouped_data.get_group('Remittance inflow')
remittance_inflow_df
# Out:
#      Year  Country Country Code              Region            Element  \
# 0    2000  Nigeria          NGA  Sub Saharan Africa  Remittance inflow
# 10   2001  Nigeria          NGA  Sub Saharan Africa  Remittance inflow
# 20   2002  Nigeria          NGA  Sub Saharan Africa  Remittance inflow
# 30   2003  Nigeria          NGA  Sub Saharan Africa  Remittance inflow
# 40   2004  Nigeria          NGA  Sub Saharan Africa  Remittance inflow
# 50   2005  Nigeria          NGA  Sub Saharan Africa  Remittance inflow
# 60   2006  Nigeria          NGA  Sub Saharan Africa  Remittance inflow
# 70   2007  Nigeria          NGA  Sub Saharan Africa  Remittance inflow
# 80   2008  Nigeria          NGA  Sub Saharan Africa  Remittance inflow
# 90   2009  Nigeria          NGA  Sub Saharan Africa  Remittance inflow
# 100  2010  Nigeria          NGA  Sub Saharan Africa  Remittance inflow
# 110  2011  Nigeria          NGA  Sub Saharan Africa  Remittance inflow
# ...

# %%
remittance_inflow_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24 entries, 0 to 230
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          24 non-null     int64
#  1   Country       24 non-null     object
#  2   Country Code  24 non-null     object
#  3   Region        24 non-null     object
#  4   Element       24 non-null     object
#  5   Unit          24 non-null     object
#  6   Scale         24 non-null     object
#  7   Value         24 non-null     object
# dtypes: int64(1), object(7)
# memory usage: 1.7+ KB

# %%
remittance_inflow_df['Value'] = remittance_inflow_df['Value'].str.replace(',', '').astype(int)
# Out:
# <ipython-input-8-429daa9d6680>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   remittance_inflow_df['Value'] = remittance_inflow_df['Value'].str.replace(',', '').astype(int)

# %%
plt.figure(figsize=(12, 6))

plt.plot(remittance_inflow_df['Year'], remittance_inflow_df['Value'])

plt.xlabel('Year')
plt.ylabel('Value (USD Millions)')
plt.title('Bangladesh Remittance inflow in USD (Millions)')

plt.show()

# %%
GDP_CP_DF = grouped_data.get_group('Gross domestic product, current prices')
GDP_CP_DF
# Out:
#      Year  Country Country Code              Region  \
# 1    2000  Nigeria          NGA  Sub Saharan Africa
# 3    2000  Nigeria          NGA  Sub Saharan Africa
# 11   2001  Nigeria          NGA  Sub Saharan Africa
# 13   2001  Nigeria          NGA  Sub Saharan Africa
# 21   2002  Nigeria          NGA  Sub Saharan Africa
# 23   2002  Nigeria          NGA  Sub Saharan Africa
# 31   2003  Nigeria          NGA  Sub Saharan Africa
# 33   2003  Nigeria          NGA  Sub Saharan Africa
# 41   2004  Nigeria          NGA  Sub Saharan Africa
# 43   2004  Nigeria          NGA  Sub Saharan Africa
# 51   2005  Nigeria          NGA  Sub Saharan Africa
# 53   2005  Nigeria          NGA  Sub Saharan Africa
# 61   2006  Nigeria          NGA  Sub Saharan Africa
# 63   2006  Nigeria          NGA  Sub Saharan Africa
# 71   2007  Nigeria          NGA  Sub Saharan Africa
# 73   2007  Nigeria          NGA  Sub Saharan Africa
# 81   2008  Nigeria          NGA  Sub Saharan Africa
# ...

# %%
GDP_CP_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48 entries, 1 to 233
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          48 non-null     int64
#  1   Country       48 non-null     object
#  2   Country Code  48 non-null     object
#  3   Region        48 non-null     object
#  4   Element       48 non-null     object
#  5   Unit          48 non-null     object
#  6   Scale         48 non-null     object
#  7   Value         48 non-null     object
# dtypes: int64(1), object(7)
# memory usage: 3.4+ KB

# %%
GDP_CP_DF['Value'] = GDP_CP_DF['Value'].str.replace(',', '').astype(float)
# Out:
# <ipython-input-14-af78ff519dfd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GDP_CP_DF['Value'] = GDP_CP_DF['Value'].str.replace(',', '').astype(float)

# %%
plt.figure(figsize=(12, 6))
plt.plot(GDP_CP_DF['Year'], GDP_CP_DF['Value'])

plt.xlabel('Year')
plt.ylabel('Value (USD Millions)')
plt.title('Bangladesh Gross domestic product, current prices in USD (Billions)')

plt.show()

# %%
def plot_grouped_data(grouped_data, group_name, value_column, title):

    df = grouped_data.get_group(group_name)
    df[value_column] = df[value_column].str.replace(',', '').astype(float)

    # Extract unit and scale
    unit = df['Unit'].iloc[0]  # Assuming unit is the same for all rows in this group
    scale = df['Scale'].iloc[0]  # Assuming scale is the same for all rows in this group

    plt.figure(figsize=(12, 6))
    plt.plot(df['Year'], df[value_column], marker='o')

    plt.xlabel('Year')
    plt.ylabel(f'{value_column} ({unit} {scale})')
    plt.title(title)

    plt.show()

# %%
unique_elements = Nigeria['Element'].unique()
print(unique_elements)
# Out:
# ['Remittance inflow' 'Gross domestic product, current prices'
#  'Percent of GDP' 'Inflation, average consumer prices'
#  'Human Development Index'
#  'Households and NPISHs Final consumption expenditure'
#  'Multidimensional poverty headcount ratio (World Bank)'
#  'Unemployment rate']

# %%
plot_grouped_data(grouped_data, 'Percent of GDP', 'Value', 'Nigeria Percent of GDP')
# Out:
# <ipython-input-17-d997afde0d71>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[value_column] = df[value_column].str.replace(',', '').astype(float)

# %%
plot_grouped_data(grouped_data, 'Inflation, average consumer prices', 'Value', 'Nigeria Inflation, average consumer prices')
# Out:
# <ipython-input-17-d997afde0d71>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[value_column] = df[value_column].str.replace(',', '').astype(float)

# %%
plot_grouped_data(grouped_data, 'Human Development Index', 'Value', 'Nigeria Human Development Index')
# Out:
# <ipython-input-17-d997afde0d71>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[value_column] = df[value_column].str.replace(',', '').astype(float)

# %%
plot_grouped_data(grouped_data, 'Households and NPISHs Final consumption expenditure', 'Value', 'Nigeria Households and NPISHs Final consumption expenditure')
# Out:
# <ipython-input-17-d997afde0d71>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[value_column] = df[value_column].str.replace(',', '').astype(float)

# %% [markdown]
# Much NaN causese this.

# %%
plot_grouped_data(grouped_data, 'Multidimensional poverty headcount ratio (World Bank)', 'Value', 'Nigeria Multidimensional poverty headcount ratio (World Bank)')
# Out:
# <ipython-input-17-d997afde0d71>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[value_column] = df[value_column].str.replace(',', '').astype(float)

# %%
plot_grouped_data(grouped_data, 'Unemployment rate', 'Value', 'Nigeria Unemployment rate')
# Out:
# <ipython-input-17-d997afde0d71>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[value_column] = df[value_column].str.replace(',', '').astype(float)
